# %%
from pymongo import MongoClient
from bson.objectid import ObjectId
from bson.decimal128 import Decimal128
import json

# %%
class JSONEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, ObjectId) or isinstance(o, Decimal128):
            return str(o)
        return json.JSONEncoder.default(self, o)

# %% [markdown]
# ## Data source
#
# If you do not change the data uri (*course_cluster_uri*), you can execute most
# of this notebook, however you will not be able to write to the database.
#
# To execute successfully the pipelines with an $out/save stage in this notebook,
# point to your own Atlas cluster into which you will have imported the *retail.csv* dataset.

# %%
# course_cluster_uri = "mongodb://agg-student:agg-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin"
course_cluster_uri = "mongodb://alexsnow348:wuthmone08@54.198.7.183:27017"
course_client = MongoClient(course_cluster_uri)

# %%
retail_col = course_client['eco']['retail']

# %%
assemble = {
    "$group": {
        "_id": {
            "InvoiceNo": "$InvoiceNo",
            "CustomerID": "$CustomerID",
            "Country": "$Country"
        },
        "InvoiceDate": { "$max": "$InvoiceDate" },
        "Items": {
            "$push": {
                "StockCode": "$StockCode",
                "Description": "$Description",
                "Quantity": "$Quantity",
                "UnitPrice": "$UnitPrice"
            }
        }
    }
}

# %%
beautify = {
    "$project": {
        "_id": "$_id.InvoiceNo",
        "InvoiceDate": "$InvoiceDate",
        "CustomerID": "$_id.CustomerID",
        "Country": "$_id.Country",
        "Items": 1
    }
}

# %%
cursor = retail_col.aggregate([
    assemble,
    beautify
  ],
  allowDiskUse=True)

# %%
retail_doc = cursor.next()

# %%
print(json.dumps(retail_doc, cls=JSONEncoder, indent=4))

# %%
computed = {
    "$addFields" : {
        "TotalPrice": {
            "$reduce": {
                "input": "$Items",
                "initialValue": Decimal128("0.00"),
                "in": {
                    "$add": [
                        "$$value",
                        { "$multiply": [ "$$this.Quantity", "$$this.UnitPrice" ] }
                    ]
                }
            }
        }
    }
}

# %%
cursor = retail_col.aggregate([
    assemble,
    beautify,
    computed
  ],
  allowDiskUse=True)

# %%
retail_doc = cursor.next()

# %%
print(json.dumps(retail_doc, cls=JSONEncoder, indent=4))

# %%
save = {
    "$out": "orders"
}

# %% [markdown]
# The following cell will **fail if you are not pointing** to your own Atlas group
# where you have write privileges to the target collection

# %%
cursor = retail_col.aggregate([
    assemble,
    beautify,
    computed,
    save
  ],
  allowDiskUse=True)

# %%
assemble = {
    "$group": {
        "_id": {
            "InvoiceNo": "$InvoiceNo",
            "CustomerID": "$CustomerID",
            "Country": "$Country",
            "InvoiceDate": { "$max": "$InvoiceDate" },
        },
        "Items": {
            "$push": {
                "StockCode": "$StockCode",
                "Description": "$Description",
                "Quantity": "$Quantity",
                "UnitPrice": "$UnitPrice"
            }
        }
    }
}

# %% [markdown]
# The following cell will show the expected error message of trying to build
# an index on *_id*, if you are pointing to your own Atlas cluster where you
# have write privileges

# %%
cursor = retail_col.aggregate([
    assemble,
    beautify,
    computed,
    save
  ],
  allowDiskUse=True)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-16-4ebc2171299c> in <module>
#       5     save
#       6   ],
# ----> 7   allowDiskUse=True)
#
# ~/miniconda3/envs/apimongo/lib/python3.7/site-packages/pymongo/collection.py in aggregate(self, pipeline, session, **kwargs)
#    2179                                    session=s,
#    2180                                    explicit_session=session is not None,
# -> 2181                                    **kwargs)
#    2182
#    2183     def aggregate_raw_batches(self, pipeline, **kwargs):
#
# ~/miniconda3/envs/apimongo/lib/python3.7/site-packages/pymongo/collection.py in _aggregate(self, pipeline, cursor_class, first_batch_size, session, explicit_session, **kwargs)
#    2086                 collation=collation,
#    2087                 session=session,
# -> 2088                 client=self.__database.client)
#    2089
#    2090             if "cursor" in result:
#
# ~/miniconda3/envs/apimongo/lib/python3.7/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write)
#     494                            self.max_bson_size, read_concern,
#     495                            parse_write_concern_error=parse_write_concern_error,
# --> 496                            collation=collation)
#     497         except OperationFailure:
#     498             raise
#
# ~/miniconda3/envs/apimongo/lib/python3.7/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation)
#     123             helpers._check_command_response(
#     124                 response_doc, None, allowable_errors,
# --> 125                 parse_write_concern_error=parse_write_concern_error)
#     126     except Exception as exc:
#     127         if publish:
#
# ~/miniconda3/envs/apimongo/lib/python3.7/site-packages/pymongo/helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     144
#     145             msg = msg or "%s"
# --> 146             raise OperationFailure(msg % errmsg, code, response)
#     147
#     148
#
# OperationFailure: insert for $out failed: { connectionId: 13, err: "E11000 duplicate key error collection: eco.tmp.agg_out.2 index: _id_ dup key: { : "536591" }", code: 11000, codeName: "DuplicateKey", n: 0, ok: 1.0 }

# %%
orders = course_client['eco']['orders']

# %%
orders.find_one()
# Out:
# {'_id': '544796',
#  'Items': [{'StockCode': '85086A',
#    'Description': 'CANDY SPOT HEART DECORATION',
#    'Quantity': 6,
#    'UnitPrice': Decimal128('0.85')}],
#  'InvoiceDate': datetime.datetime(2011, 2, 23, 13, 37),
#  'CustomerID': '16208',
#  'Country': 'United Kingdom',
#  'TotalPrice': Decimal128('5.10')}

# %%
pipeline_ = [
    {
        '$addFields': {
            'total_quantity': {
                '$sum': '$Items.Quantity'
            }, 
            'num_items': {
                '$size': '$Items'
            }
        }
    }, {
        '$limit': 1
    }
]

# %%
cursor = orders.aggregate(pipeline_)

# %%
list(cursor)
# Out:
# [{'_id': '544796',
#   'Items': [{'StockCode': '85086A',
#     'Description': 'CANDY SPOT HEART DECORATION',
#     'Quantity': 6,
#     'UnitPrice': Decimal128('0.85')}],
#   'InvoiceDate': datetime.datetime(2011, 2, 23, 13, 37),
#   'CustomerID': '16208',
#   'Country': 'United Kingdom',
#   'TotalPrice': Decimal128('5.10'),
#   'total_quantity': 6,
#   'num_items': 1}]
