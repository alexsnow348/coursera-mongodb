# %%
from pymongo import MongoClient
import pprint

# %%
client = MongoClient("mongodb://94.237.65.67:37017")
qmsdata = client['acedb']['qms']

# %%
from datetime import datetime
today = datetime.now()
today = today.strftime("%Y%m%d")

# %%
todaydata = qmsdata.find({"date" : { "$eq" : today}}) 
firstdaydata = qmsdata.find({"date" : { "$eq" : "20190101"}}  )

# %%
firstdaydata.count()
# Out:
# /home/wuthmone/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 173

# %%
todaydata_l = list(todaydata)
firstdaydata_l = list(firstdaydata)
data = []
for each in todaydata_l:
    for item in firstdaydata_l:
        if each['premise_name'] == item['premise_name']:
            data_today = each['qms_data'][len(each['qms_data'])-1]
            data_first = item['qms_data'][len(item['qms_data'])-1]
            if data_first['serveCount']==data_today['serveCount']:
                data.append({"premise_name":each['premise_name'],"serveCount":data_today['serveCount']})
# Out:
# 'TAD Aeon Kempas Bandar Dato Onn'
# 'TAD Air Itam'
# 'TAD Alamanda'
# 'TAD Ampang'
# 'TAD BP Mall'
# 'TAD Bahau'
# 'TAD Balakong'
# 'TAD Bandar Alma'
# 'TAD Bandar Puteri Puchong'
# 'TAD Bangi'
# 'TAD Bukit Gambir'
# 'TAD Bukit Tinggi'
# 'TAD Cheng Baru'
# 'TAD Cheras'
# 'TAD Enstek'
# 'TAD Equine Park'
# 'TAD Gelang Patah'
# 'TAD Gua Musang'
# 'TAD Gunung Rapat'
# 'TAD Inanam'
# 'TAD Jerantut'
# 'TAD Johor Jaya'
# 'TAD Kelana Jaya'
# 'TAD Kepala Batas'
# 'TAD Kota Belud'
# 'TAD Kota Kemuning'
# 'TAD Kubang Kerian'
# 'TAD Kuchai Lama'
# 'TAD Low Yat'
# 'TAD Malim Jaya'
# 'TAD Maluri'
# 'TAD Masai'
# 'TAD Masjid Tanah'
# 'TAD Melaka Raya'
# 'TAD Melawati'
# 'TAD Merlimau'
# 'TAD Meru Bestari'
# 'TAD Mid Valley'
# 'TAD Mont Kiara'
# 'TAD Mukah'
# 'TAD Mutiara Mas'
# 'TAD Nilai'
# 'TAD Parit Raja'
# 'TAD Penampang'
# 'TAD Perdana Jaya'
# 'TAD Permy Jaya'
# 'TAD Prima Saujana'
# 'TAD Puchong Utama'
# 'TAD Putatan'
# 'TAD Putra Height'
# 'TAD Saujana Utama'
# 'TAD Selayang'
# 'TAD Semenyih'
# 'TAD Senawang'
# 'TAD Sentul'
# 'TAD Serdang'
# 'TAD Seremban 2'
# 'TAD Seri Iskandar'
# 'TAD Seri Manjung'
# 'TAD Setia Alam'
# 'TAD Setia Indah'
# 'TAD Setia Tropika'
# 'TAD Sg. Buloh'
# 'TAD Sg. Wang'
# 'TAD Shah Alam S7'
# 'TAD Sri Gombak'
# 'TAD Sri Permaisuri'
# 'TAD Sri Petaling'
# 'TAD Subang Jaya'
# 'TAD Sunway Damansara'
# 'TAD Taman Universiti'
# 'TAD Tangkak'
# 'TAD Tanjung Tokong'
# 'TAD Temerloh'
# 'TAD Tmn Tuanku Haminah'
# 'TAD Triang'
# 'TAD UTC Johor'
# 'TAD UTC KL'
# 'TAD UTC Kuching'
# 'TAD UTC Melaka'
# 'TAD Ulu Tiram'
# 'TAD Wangsa Maju'
# 'TAD eCurve'
# 'TMpoint Alor Gajah'
# 'TMpoint Alor Setar'
# 'TMpoint Banting'
# 'TMpoint Batu Gajah'
# 'TMpoint Batu Lintang Kuching'
# 'TMpoint Batu Pahat'
# 'TMpoint Bayan Baru'
# 'TMpoint Beauford'
# 'TMpoint Bentong'
# 'TMpoint Bintulu'
# 'TMpoint Bukit Mertajam'
# 'TMpoint Bukit Raja Selangor'
# 'TMpoint Butterworth'
# 'TMpoint Cyberjaya'
# 'TMpoint Damansara Utama'
# 'TMpoint Dungun'
# 'TMpoint Ipoh'
# 'TMpoint Ipoh Tasek'
# 'TMpoint Jerteh'
# 'TMpoint Jitra'
# 'TMpoint Jln Burmah Penang'
# 'TMpoint K. Kubu Bharu'
# 'TMpoint Kajang'
# 'TMpoint Kampar'
# 'TMpoint Kangar'
# 'TMpoint Kemaman'
# 'TMpoint Keningau'
# 'TMpoint Kepong'
# 'TMpoint Kluang'
# 'TMpoint Kota Bharu'
# 'TMpoint Kota Tinggi'
# 'TMpoint Kuala Kangsar'
# 'TMpoint Kuala Krai'
# 'TMpoint Kuala Pilah'
# 'TMpoint Kuala Selangor'
# 'TMpoint Kuala Terengganu'
# 'TMpoint Kuantan'
# 'TMpoint Kudat'
# 'TMpoint Kulai'
# 'TMpoint Kulim'
# 'TMpoint Labuan'
# 'TMpoint Lahad Datu'
# 'TMpoint Langkawi'
# 'TMpoint Limbang'
# 'TMpoint MITC'
# 'TMpoint Melaka'
# 'TMpoint Mentakab'
# 'TMpoint Mersing'
# 'TMpoint Miri'
# 'TMpoint Muar'
# 'TMpoint Muzium'
# 'TMpoint Pandan Indah'
# 'TMpoint Parit Buntar'
# 'TMpoint Pasir Gudang'
# 'TMpoint Pasir Mas'
# 'TMpoint Pekan'
# 'TMpoint Pelangi'
# 'TMpoint Pontian'
# 'TMpoint Port Dickson'
# 'TMpoint Quill Mall'
# 'TMpoint Raub'
# 'TMpoint Rawang'
# 'TMpoint Sadong Jaya Kota Kinabalu'
# 'TMpoint Sandakan'
# 'TMpoint Sarikei'
# 'TMpoint Segamat'
# 'TMpoint Seremban'
# 'TMpoint Setapak'
# 'TMpoint Shah Alam'
# 'TMpoint Sibu'
# 'TMpoint Sitiawan'
# 'TMpoint Skudai'
# 'TMpoint Sri Aman'
# 'TMpoint Sungai Bakap'
# 'TMpoint Sungai Petani'
# 'TMpoint TMEC'
# 'TMpoint Taipan'
# 'TMpoint Taiping'
# 'TMpoint Taman Desa'
# 'TMpoint Tampin'
# 'TMpoint Tanah Merah'
# 'TMpoint Tanjung Malim'
# 'TMpoint Tapah'
# 'TMpoint Tawau'
# 'TMpoint Teluk Intan'
# 'TMpoint Yong Peng'
# 'Teras Semenyih'
# 'Teras Seremban'
# 'Test Ent Damansara'
# 'Test Ent Putrajaya'

# %%
# pprint.pprint(firstdaydata[0])
print(len(data))
# Out:
# 63

# %%
pprint.pprint(data)
# Out:
# [{'premise_name': 'TAD Aeon Kempas Bandar Dato Onn', 'serveCount': 0},
#  {'premise_name': 'TAD Alamanda', 'serveCount': 0},
#  {'premise_name': 'TAD Ampang', 'serveCount': 6},
#  {'premise_name': 'TAD Bandar Puteri Puchong', 'serveCount': 10},
#  {'premise_name': 'TAD Gunung Rapat', 'serveCount': 0},
#  {'premise_name': 'TAD Inanam', 'serveCount': 2},
#  {'premise_name': 'TAD Kelana Jaya', 'serveCount': 0},
#  {'premise_name': 'TAD Kepala Batas', 'serveCount': 4},
#  {'premise_name': 'TAD Kota Belud', 'serveCount': 0},
#  {'premise_name': 'TAD Kubang Kerian', 'serveCount': 0},
#  {'premise_name': 'TAD Low Yat', 'serveCount': 0},
#  {'premise_name': 'TAD Maluri', 'serveCount': 3},
#  {'premise_name': 'TAD Melaka Raya', 'serveCount': 0},
#  {'premise_name': 'TAD Meru Bestari', 'serveCount': 0},
#  {'premise_name': 'TAD Mid Valley', 'serveCount': 0},
#  {'premise_name': 'TAD Prima Saujana', 'serveCount': 0},
#  {'premise_name': 'TAD Selayang', 'serveCount': 4},
#  {'premise_name': 'TAD Serdang', 'serveCount': 3},
#  {'premise_name': 'TAD Shah Alam S7', 'serveCount': 0},
#  {'premise_name': 'TAD Subang Jaya', 'serveCount': 0},
#  {'premise_name': 'TAD Sunway Damansara', 'serveCount': 4},
#  {'premise_name': 'TAD UTC Johor', 'serveCount': 5},
#  {'premise_name': 'TAD UTC KL', 'serveCount': 0},
#  {'premise_name': 'TAD UTC Kuching', 'serveCount': 0},
#  {'premise_name': 'TAD Wangsa Maju', 'serveCount': 0},
#  {'premise_name': 'TAD eCurve', 'serveCount': 0},
#  {'premise_name': 'TMpoint Alor Setar', 'serveCount': 0},
#  {'premise_name': 'TMpoint Batu Lintang Kuching', 'serveCount': 16},
#  {'premise_name': 'TMpoint Bayan Baru', 'serveCount': 21},
#  {'premise_name': 'TMpoint Bukit Mertajam', 'serveCount': 10},
#  {'premise_name': 'TMpoint Bukit Raja Selangor', 'serveCount': 19},
#  {'premise_name': 'TMpoint Butterworth', 'serveCount': 26},
#  {'premise_name': 'TMpoint Damansara Utama', 'serveCount': 10},
#  {'premise_name': 'TMpoint Ipoh', 'serveCount': 16},
#  {'premise_name': 'TMpoint Jln Burmah Penang', 'serveCount': 20},
#  {'premise_name': 'TMpoint Kajang', 'serveCount': 11},
#  {'premise_name': 'TMpoint Kangar', 'serveCount': 6},
#  {'premise_name': 'TMpoint Kepong', 'serveCount': 6},
#  {'premise_name': 'TMpoint Kota Bharu', 'serveCount': 0},
#  {'premise_name': 'TMpoint Kuala Terengganu', 'serveCount': 0},
#  {'premise_name': 'TMpoint Kuantan', 'serveCount': 12},
#  {'premise_name': 'TMpoint Kulai', 'serveCount': 0},
#  {'premise_name': 'TMpoint Kulim', 'serveCount': 0},
#  {'premise_name': 'TMpoint Melaka', 'serveCount': 14},
#  {'premise_name': 'TMpoint Muzium', 'serveCount': 3},
#  {'premise_name': 'TMpoint Pandan Indah', 'serveCount': 11},
#  {'premise_name': 'TMpoint Pelangi', 'serveCount': 0},
#  {'premise_name': 'TMpoint Pontian', 'serveCount': 0},
#  {'premise_name': 'TMpoint Quill Mall', 'serveCount': 0},
#  {'premise_name': 'TMpoint Rawang', 'serveCount': 0},
#  {'premise_name': 'TMpoint Sadong Jaya Kota Kinabalu', 'serveCount': 18},
#  {'premise_name': 'TMpoint Seremban', 'serveCount': 0},
#  {'premise_name': 'TMpoint Setapak', 'serveCount': 9},
#  {'premise_name': 'TMpoint Shah Alam', 'serveCount': 16},
#  {'premise_name': 'TMpoint Skudai', 'serveCount': 0},
#  {'premise_name': 'TMpoint Sungai Bakap', 'serveCount': 0},
#  {'premise_name': 'TMpoint Sungai Petani', 'serveCount': 0},
#  {'premise_name': 'TMpoint Taipan', 'serveCount': 15},
#  {'premise_name': 'TMpoint Taman Desa', 'serveCount': 15},
#  {'premise_name': 'Teras Semenyih', 'serveCount': 26},
#  {'premise_name': 'Teras Seremban', 'serveCount': 0},
#  {'premise_name': 'Test Ent Damansara', 'serveCount': 26},
#  {'premise_name': 'Test Ent Putrajaya', 'serveCount': 0}]
